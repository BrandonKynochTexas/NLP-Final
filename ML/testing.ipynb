# %%
# Fetch Fin Viz Article Links

from urllib.request import Request, urlopen
from bs4 import BeautifulSoup # For extracting contents of html pages

request = Request(
    url = "https://finviz.com/quote.ashx?t=GOOG&p=d",
    headers={'User-Agent': 'Mozilla/5.0'}
)

html = urlopen(request).read()

soup = BeautifulSoup(html, 'html.parser')

l = soup.findAll("div", {"class":"news-link-container"})

for div in l:
    for i in div.findAll("a"):
        print(i['href'])
# Out:
# https://finance.yahoo.com/m/98869e1e-b8b1-39bd-8424-486a86c346e2/tiktok%2C-twitter%2C-meta-face.html
# https://finance.yahoo.com/video/microsoft-alphabet-earnings-expect-143940125.html
# https://finance.yahoo.com/video/stocks-trade-lower-open-investors-134700691.html
# https://finance.yahoo.com/m/07be4bbb-f67f-3942-b632-8eae330fe8d0/is-google-stock-a-buy-with.html
# https://finance.yahoo.com/m/7c2d0d1b-ce2c-3e98-bc1b-28088e302321/google-ad-revenue-expected-to.html
# https://finance.yahoo.com/video/alphabet-microsoft-earnings-expect-call-000018466.html
# https://finance.yahoo.com/news/microsoft-earnings-ai-hype-could-take-backseat-to-cloud-growth-troubles-201023413.html
# https://finance.yahoo.com/news/alphabet-earnings-ai-cost-cuts-take-center-stage-185507416.html
# https://finance.yahoo.com/video/tech-layoffs-smaller-companies-still-170446869.html
# https://finance.yahoo.com/news/coke-exploring-ways-to-leverage-ai-because-every-company-needs-an-ai-strategy-now-160228764.html
# https://finance.yahoo.com/m/f5cebda1-9e54-38e8-acf7-78f289d62def/big-tech-depends-on-ai.html
# https://finance.yahoo.com/news/amazon-microsoft-meta-alphabet-lead-earnings-rush-what-to-know-this-week-114436466.html
# https://finance.yahoo.com/m/09d7be44-14bc-3d87-a295-b422795c427f/amazon%2C-facebook%2C-google.html
# https://finance.yahoo.com/m/f83720db-7dab-3ea2-8b08-b57c6351d3d6/google-ceo-sundar-pichai%E2%80%99s.html
# https://finance.yahoo.com/video/metadata-yf-explains-100059209.html
# https://finance.yahoo.com/m/b3ce31d4-f245-36f3-b60d-2fcd8bfd02d0/stocks-notch-weekly-losses-as.html
# https://finance.yahoo.com/video/lyft-layoffs-very-consistent-weve-192801798.html
# https://finance.yahoo.com/news/ukraine-latest-russia-accidentally-bombs-070022828.html
# https://finance.yahoo.com/m/738374bf-c948-3304-a7c1-531d26bd7225/google-looks-to-turbocharge.html
# https://finance.yahoo.com/m/738374bf-c948-3304-a7c1-531d26bd7225/alphabet%E2%80%99s-google-combines-ai.html
# https://finance.yahoo.com/video/tech-stocks-perform-fed-pauses-180054321.html
# https://finance.yahoo.com/news/nine-states-join-doj-lawsuit-to-breakup-googles-ad-tech-tool-stranglehold-144923381.html
# https://finance.yahoo.com/news/techs-new-ai-war-is-actually-about-search-morning-brief-130039335.html
# https://finance.yahoo.com/news/are-investors-behaving-irrationally-123527446.html
# https://finance.yahoo.com/video/todays-top-stories-googles-ai-210828417.html
# https://finance.yahoo.com/video/google-remains-leader-ai-despite-201345816.html
# https://finance.yahoo.com/video/ai-concerns-tremendous-ethical-questions-193404899.html
# https://finance.yahoo.com/video/regulation-necessary-framework-professor-182035101.html
# https://finance.yahoo.com/news/google-stock-drops-about-3-amid-concerns-about-ai-competitiveness-161839424.html
# https://finance.yahoo.com/m/7b271adc-ee0a-3a3c-990e-627ab0e6bc23/microsoft-could-inflate.html
# https://finance.yahoo.com/m/f72ca08e-a20d-3ed8-86f8-6ee52ed66593/analyst-report%3A-alphabet-inc..html
# https://finance.yahoo.com/video/alphabet-stock-declines-following-google-131721588.html
# https://finance.yahoo.com/m/69852486-621d-30ef-9be6-f6b96cc7880e/gm-ditches-apple-carplay-on.html
# https://finance.yahoo.com/video/lone-amazon-bear-optimistic-companys-215044886.html
# https://finance.yahoo.com/video/google-microsoft-ai-services-very-203715663.html
# https://finance.yahoo.com/video/chatgpt-help-trade-stocks-164841806.html
# https://finance.yahoo.com/m/99f7d325-6c10-3d13-904f-a7e067f3f8a7/google-asks-judge-to-end-doj.html
# https://finance.yahoo.com/m/e1db766b-777e-3e55-879d-fe5bea7f9fa6/amazon-joins-microsoft%2C.html
# https://finance.yahoo.com/m/99f7d325-6c10-3d13-904f-a7e067f3f8a7/google-to-ask-judge-to-end.html
# https://finance.yahoo.com/video/earnings-season-stock-biggest-bellwether-205348040.html
# https://finance.yahoo.com/news/tech-stocks-rally-as-investors-ask-when-do-things-start-looking-good-again-190001472.html
# https://finance.yahoo.com/news/tech-stocks-rally-as-investors-ask--when-do-things-start-looking-good-again-190001160.html
# https://finance.yahoo.com/m/a04c4364-6fe1-389a-8691-50585a977d3b/what-is-chatgpt%3F-what-to-know.html
# https://finance.yahoo.com/video/tuesday-top-stories-ny-fed-210608567.html
# https://finance.yahoo.com/video/youtube-reveals-nfl-sunday-ticket-200047384.html
# https://finance.yahoo.com/news/meta-is-giving-the-market-what-it-wants-analyst-says-191031349.html
# https://finance.yahoo.com/m/4936d92b-8fd6-3702-9028-d31d21ea5901/nfl-sunday-ticket-package-is.html
# https://finance.yahoo.com/m/fbdacf59-b79b-3b3e-be18-7092ad3878c4/south-korea-fines-google-%2432.html
# https://finance.yahoo.com/video/delete-tiktok-yf-explains-005943947.html
# https://finance.yahoo.com/video/next-refresh-cycle-pc-makers-210137154.html
# https://finance.yahoo.com/m/d386c951-a65e-3ed8-bd5c-756300a52e74/as-tech-jobs-disappear%2C.html
# https://finance.yahoo.com/m/d61304b4-2397-37cc-96f0-07f02a1d6c5f/google-ceo-on-ai%2C-the-future.html
# https://finance.yahoo.com/m/9a8a67a5-2f7f-3dde-8e1e-a322b48b028b/is-big-tech%E2%80%99s-r%26d-spending.html
# https://finance.yahoo.com/m/5d4d0ac6-c058-351f-8eb3-78139f4deb6d/corrections-%26-amplifications.html
# https://finance.yahoo.com/m/63f0b06c-e5e6-385d-8f7a-e1b973145903/he%E2%80%99s-been-dead-for-nearly-10.html
# https://finance.yahoo.com/m/07be4bbb-f67f-3942-b632-8eae330fe8d0/is-google-a-better-buy-than.html
# https://finance.yahoo.com/news/why-speculative-ai-stocks-like-c3ai-and-bigbearai-are-seeing-monster-volatility-123221071.html
# https://finance.yahoo.com/m/5292ee51-698f-3cff-a7cf-fe5173f41f82/google-ceo-sundar-pichai-says.html
# https://finance.yahoo.com/news/silicon-valley-is-starting-to-kill-some-of-its-famously-lavish-perks-192204600.html
# https://finance.yahoo.com/news/silicon-valley-is-starting-to-kill-some-its-famously-lavish-perks-192204904.html
# https://finance.yahoo.com/video/stock-hype-needs-pared-back-213807493.html
# https://finance.yahoo.com/news/congressional-leaders-set-to-warn-hollywood-silicon-valley-leaders-on-china-ties-205807182.html
# https://finance.yahoo.com/news/meta-is-teaching-robots-how-to-move-on-their-own-175757197.html
# https://finance.yahoo.com/news/cfpb-director-chopra-says-fsoc-must-seriously-consider-big-tech-oversight-230205724.html
# https://finance.yahoo.com/video/cfpb-director-questions-payment-companies-221334698.html
# https://finance.yahoo.com/video/google-needs-stronger-leader-analyst-213924771.html
# https://finance.yahoo.com/video/walt-disney-company-florida-another-194813355.html
# https://finance.yahoo.com/news/tipranks-perfect-10-list-stock-085902079.html
# https://finance.yahoo.com/news/3-things-you-may-have-missed-as-markets-wrapped-up-a-first-quarter-rally-101738661.html
# https://finance.yahoo.com/m/e9c478d3-21fe-36eb-a9a6-d18639bfc07a/google-co-founder%2C-other.html
# https://finance.yahoo.com/video/gm-drops-apple-carplay-partners-194732306.html
# https://finance.yahoo.com/m/e49cf681-7520-370c-b742-18587d3ec74b/google-cfo-signals-more.html
# https://finance.yahoo.com/news/the-first-quarter-of-the-year-sent-investors-back-to-the-future-morning-brief-093034637.html
# https://finance.yahoo.com/video/investors-giving-eye-toward-big-194806136.html
# https://finance.yahoo.com/news/microsoft-is-dominating-the-ai-warsfor-now-200037880.html
# https://finance.yahoo.com/m/5951e4eb-0696-3054-bcb3-c9604490d38f/elon-musk%2C-other-ai-experts.html
# https://finance.yahoo.com/video/why-banks-waging-digital-wallet-165600093.html
# https://finance.yahoo.com/m/07be4bbb-f67f-3942-b632-8eae330fe8d0/is-google-a-buy-amid-tougher.html
# https://finance.yahoo.com/news/tech-layoffs-yes-theres-a-better-way-to-fire-people-is-big-tech-doing-it-no-way-151409888.html
# https://finance.yahoo.com/m/5951e4eb-0696-3054-bcb3-c9604490d38f/elon-musk%2C-other-ai-bigwigs.html
# https://finance.yahoo.com/m/13dc1b3d-cbbd-3f8a-9b04-5e98baf3968c/youtube-looking-into-gandhi%E2%80%99s.html
# https://finance.yahoo.com/video/three-biggest-trends-retail-today-013129753.html
# https://finance.yahoo.com/m/e764fdf6-f52b-3b99-a4ae-9f63d76c701b/nfl%2C-redbird-team-up-to.html
# https://finance.yahoo.com/video/alibaba-stock-continues-climb-announcement-195259651.html
# https://finance.yahoo.com/news/microsoft-is-bringing-chatgpt-technology-to-cybersecurity-153003566.html
# https://finance.yahoo.com/video/stocks-trade-mixed-open-rate-134215964.html
# https://finance.yahoo.com/news/cibc-introduces-additional-canadian-depositary-120000142.html
# https://finance.yahoo.com/m/03cf21c9-4a9a-3452-8da2-c4b3a806cbc1/microsoft%2C-google%2C-amazon.html
# https://finance.yahoo.com/news/pinterest-ceo-were-making-ai-additive-to-peoples-lives-not-addictive-210749363.html
# https://finance.yahoo.com/m/aba3d9e5-caaa-3f84-a0b9-b46f37d67799/publishers-prepare-for.html
# https://finance.yahoo.com/m/07be4bbb-f67f-3942-b632-8eae330fe8d0/is-google-a-buy-amid-banking.html
# https://finance.yahoo.com/news/panera-bread-palm-scanners-provide-another-level-of-convenience-personalized-service-ceo-180300163.html
# https://finance.yahoo.com/video/ai-going-change-way-100509310.html
# https://finance.yahoo.com/video/theres-distinct-possibility-tiktok-actually-201138067.html
# https://finance.yahoo.com/m/3b6a85fa-2a67-3980-b15a-4570eb82d67d/google-made-the-bard-ai.html
# https://finance.yahoo.com/video/bard-vs-chatgpt-vs-bing-161800099.html
# https://finance.yahoo.com/news/what-young-tiktok-creators-think-about-a-possible-ban-people-will-freak-out-152523231.html
# https://finance.yahoo.com/m/9b807972-27ea-37c2-ac03-bf60ebc982fe/ukraine-war-shows-difficulty.html
# https://finance.yahoo.com/news/the-fed-gave-stocks-a-reprieve-but-the-all-clear-is-a-ways-off-morning-brief-093016419.html
# https://finance.yahoo.com/video/tiktok-catalyst-something-much-bigger-185736827.html

# %%
from bs4 import BeautifulSoup # For extracting contents of html pages

from selenium import webdriver
from selenium.webdriver.support.wait import WebDriverWait 
from selenium.webdriver.common.by import By
import selenium.webdriver.support.expected_conditions as EC
 
# Create webdriver object
driver = webdriver.Chrome()
driver.get("https://www.fool.com/quote/nasdaq/googl/")

load_more_clicks_count = 10
for i in range(load_more_clicks_count):
    load_more_button = driver.find_element(By.XPATH, '//*[@id="quote-news-analysis"]/div[3]/div[1]/button')
    # Scroll to load more button
    driver.execute_script("arguments[0].scrollIntoView();", load_more_button)
    # Wait until button is visible
    WebDriverWait(driver, 20).until(EC.visibility_of_element_located((By.XPATH, '//*[@id="quote-news-analysis"]/div[3]/div[1]/button')))
    # Wait until button is clickable, then click
    driver.execute_script(
        "arguments[0].click();",
        WebDriverWait(driver, 20).until(EC.element_to_be_clickable((By.XPATH, '//*[@id="quote-news-analysis"]/div[3]/div[1]/button')))
    )
    print(f'Loading Motley Fool articles: ({i}/{load_more_clicks_count})')
    # Wait until loading indicator is hidden
    WebDriverWait(driver, 20).until(EC.invisibility_of_element_located((By.XPATH, '//*[@id="quote-news-analysis"]/div[3]/div[1]/button/svg')))
    # Sometimes the WebDriverWait events still exit early so we wait a little bit extra (This isn't ideal solution)
    driver.implicitly_wait(1)

html = driver.page_source

driver.close()

soup = BeautifulSoup(html, 'html.parser')

l = soup.findAll("div", {"id":"news-analysis-container"})

links = []
for div in l:
    for i in div.findAll("a"):
        href = i['href']
        if href.startswith('http'): # Motley fool related article links don't start with HTTPs, although some links like ads/sign up links exist in this div
            continue
        if href.startswith('/terms'): # Discard unrelated articles - Eg https://fool.com/terms/d/digital wallet
            continue
        # We are only interested in links containing the date prefix
        # Relevant links should start with investing/{date}/
        if href.startswith('/investing/20'):
            links.append(f'https://fool.com{href}')

links_count_with_duplicates = len(links)
links = list(set(links)) # Convert to set and back to list to remove duplicate links
if links_count_with_duplicates - len(links) > 0:
    print(f'WARNING (Motley links):\t {links_count_with_duplicates - len(links)} duplicate links found and removed')

for link in links:
    print(link)
# Out:
# Loading Motley Fool articles: (0/10)
# Loading Motley Fool articles: (1/10)
# Loading Motley Fool articles: (2/10)
# Loading Motley Fool articles: (3/10)
# Loading Motley Fool articles: (4/10)
# Loading Motley Fool articles: (5/10)
# Loading Motley Fool articles: (6/10)
# Loading Motley Fool articles: (7/10)
# Loading Motley Fool articles: (8/10)
# Loading Motley Fool articles: (9/10)
# https://fool.com/investing/2023/04/01/my-top-faang-stock-to-buy-second-half-of-2023/
# https://fool.com/investing/2023/04/21/fed-recession-1-faang-stock-to-buy-and-1-to-avoid/
# https://fool.com/investing/2023/04/14/2-tech-stocks-to-buy-and-hold-for-the-next-decade/
# https://fool.com/investing/2023/04/23/ai-revolution-2-artificial-intelligence-stocks-bil/
# https://fool.com/investing/2023/04/07/alphabets-youtube-has-a-magnificent-future-heres-w/
# https://fool.com/investing/2023/04/06/how-to-find-undervalued-stocks-heres-where-i-start/
# https://fool.com/investing/2023/04/03/4-top-stocks-to-buy-in-april/
# https://fool.com/investing/2023/04/21/bing-is-already-taking-market-share-from-google-ti/
# https://fool.com/investing/2023/03/13/alphabet-stock-bear-vs-bull/
# https://fool.com/investing/2023/04/06/why-alphabet-stock-was-moving-higher-today/
# https://fool.com/investing/2023/04/15/want-1-million-in-retirement-invest-295000-in-thes/
# https://fool.com/investing/2023/04/04/how-microsoft-and-google-will-change-the-future-of/
# https://fool.com/investing/2023/04/17/the-ai-search-war-up-google-switch-microsoft-bing/
# https://fool.com/investing/2023/03/08/my-top-faang-stock-to-buy-for-the-second-half-of-2/
# https://fool.com/investing/2023/04/22/a-bull-market-is-coming-2-faang-stocks-to-buy-righ/
# https://fool.com/investing/2023/04/17/alphabet-investors-shouldnt-sleep-on-this-sleeping/
# https://fool.com/investing/2023/04/24/prediction-these-3-tech-stocks-will-be-worth-more/
# https://fool.com/investing/2023/03/23/stocks-join-apple-microsoft-in-2-trillion-club/
# https://fool.com/investing/2023/03/19/this-chatbot-stock-presents-a-once-in-a-lifetime-b/
# https://fool.com/investing/2023/03/14/the-svb-ripple-effect-may-continue-to-affect-the-c/
# https://fool.com/investing/2023/04/07/if-i-could-only-buy-1-stock-this-would-be-it/
# https://fool.com/investing/2023/03/21/why-alphabet-palantir-and-other-ai-stocks-rallied/
# https://fool.com/investing/2023/03/31/dont-wait-until-the-dip-is-over-to-buy-these-2-mag/
# https://fool.com/investing/2023/03/17/5-top-stocks-to-buy-right-now/
# https://fool.com/investing/2023/04/07/a-bull-market-is-coming-2-reasons-to-buy-alphabet/
# https://fool.com/investing/2023/03/28/is-alphabet-a-good-ai-stock-to-buy-right-now/
# https://fool.com/investing/2023/03/31/googles-owner-has-more-money-than-it-knows-what-to/
# https://fool.com/investing/2023/03/16/falling-inflation-lifting-nasdaq-2-stocks-buy-fist/
# https://fool.com/investing/2023/03/14/why-alphabet-shopify-and-meta-platforms-stocks-all/
# https://fool.com/investing/2023/03/06/top-value-stock-to-buy-right-now/
# https://fool.com/investing/2023/04/21/3-red-flags-for-alphabet-future/
# https://fool.com/investing/2023/03/13/why-alphabet-stock-rallied-monday-morning/
# https://fool.com/investing/2023/03/27/why-did-google-invest-300-million-in-a-chatgpt-com/
# https://fool.com/investing/2023/03/14/why-is-everyone-talking-artificial-intelligence-ai/
# https://fool.com/investing/2023/04/16/ai-revolution-2-ai-stocks-billionaires-are-buying/
# https://fool.com/investing/2023/03/20/beyond-semiconductors-how-cloud-service-providers/
# https://fool.com/investing/2023/03/16/a-bull-market-is-coming-2-reasons-to-buy-alphabet/
# https://fool.com/investing/2023/04/11/is-google-challenging-nvidia-or-aiming-at-microsof/
# https://fool.com/investing/2023/03/16/why-alphabet-stock-climbed-today/
# https://fool.com/investing/2023/03/15/alphabet-means-business-and-flexed-its-muscles/
# https://fool.com/investing/2023/03/14/1-faang-stock-to-buy-in-march-1-avoid-like-plague/
# https://fool.com/investing/2023/03/21/googles-exclusive-photo-tool-does-double-duty/
# https://fool.com/investing/2023/03/24/google-buys-more-gitlab-stock-what-investors-need/
# https://fool.com/investing/2023/04/08/if-i-had-to-allocate-1000-between-3-ai-stocks/
# https://fool.com/investing/2023/04/06/is-google-challenging-nvidia/
# https://fool.com/investing/2023/04/21/microsoft-and-alphabet-the-ai-battle-continues/
# https://fool.com/investing/2023/04/01/nasdaq-bear-market-5-growth-stocks-regret-not-buy/
# https://fool.com/investing/2023/03/29/history-shows-why-now-could-be-a-once-in-a-decade/
# https://fool.com/investing/2023/04/06/prediction-this-will-be-largest-ai-stock-in-2030/
# https://fool.com/investing/2023/04/07/the-first-5-stocks-id-buy-if-i-had-to-start-over/
# https://fool.com/investing/2023/04/13/why-alphabet-stock-was-up-today/
# https://fool.com/investing/2023/04/03/why-alphabet-stock-gained-15-in-march/
# https://fool.com/investing/2023/04/21/alphabet-just-made-a-huge-move-in-the-race-to-domi/

# %%
# https://finance.yahoo.com/video/salesforce-ceo-marc-benioff-were-033045094.html
import torch
from transformers import MarkupLMProcessor, MarkupLMForQuestionAnswering

from urllib.request import Request, urlopen
from bs4 import BeautifulSoup # For extracting contents of html pages

request = Request(
    url = "https://finance.yahoo.com/video/salesforce-ceo-marc-benioff-were-033045094.html",
    headers={'User-Agent': 'Mozilla/5.0'}
)

processor = MarkupLMProcessor.from_pretrained("microsoft/markuplm-base-finetuned-websrc")
model = MarkupLMForQuestionAnswering.from_pretrained("microsoft/markuplm-base-finetuned-websrc")

# html = str(urlopen(request).read())
# print(html)

html = """
<html id=atomic class="Fz(62.5%) Pos(r)     desktop bktfd-qsp-seqmsg-stickyfooter ua-safari ua-16.3" lang=en-US>
<head>
    <script>
    window.performance.mark('PageStart');
    document.documentElement.className += ' JsEnabled jsenabled';
    /**
            * Empty darlaOnready method, to avoid JS error.
            * This can happen when Async Darla JS file is loaded earlier than Darla Proxy JS.
            * This method will be overridden by Darla Proxy
            */
    window.darlaOnready = function() {};
    </script>
    <title>Salesforce CEO Marc Benioff: This Is How We're Going To Win</title>
    <meta http-equiv=content-type content="text/html; charset=utf-8">
    <meta http-equiv=x-dns-prefetch-control content=on>
    <meta http-equiv=X-UA-Compatible content=chrome =1>
    <meta name="oath:guce:consent-host" content="guce.yahoo.com">
    <meta name="news_keywords" content="Marc Benioff, Brian Sozzi, Brad Smith, Salesforce, Julie Hyman, succession plans"/>
    <meta name="twitter:title" content="Salesforce CEO Marc Benioff: This Is How We&#x27;re Going To Win"/>
    <meta property="og:title" content="Salesforce CEO Marc Benioff: This Is How We&#x27;re Going To Win"/>
    <meta property="og:url" content="https://finance.yahoo.com/video/salesforce-ceo-marc-benioff-were-033045094.html"/>
    <meta property="al:android:url" content="yfinance://article/4019e7c7-cc93-301b-a999-644d823651be"/>
    <link rel="amphtml" href="https://finance.yahoo.com/amphtml/video/salesforce-ceo-marc-benioff-were-033045094.html"/>
    <meta name="twitter:description" content="Salesforce Co-Founder and CEO Marc Benioff joins Yahoo Finance&#x2019;s Brian Sozzi to discuss the company&#x27;s latest earnings, succession plans, activist investors targeting Salesforce, the AI phenomenon, and much more. Be sure to tune into Yahoo Finance Live Programming on Thursday, March 2:- 9am ET:&#x26;nbsp; Brian Sozzi joins Yahoo Finance&#x2019;s Julie Hyman and Brad Smith with his key takeaways from the Marc Benioff interview and the company&#x2019;s next steps- 11am ET: Salesforce Analyst breaks down the company&#x2019;s earnings with Yahoo Finance&#x2019;s Rachelle Akuffo- 3:00pm ET: Dave Briggs and Seana Smith talk with Constellation Research Principal Analyst &#x26; Founder Ray Wang"/>
    <meta name="description" content="Salesforce Co-Founder and CEO Marc Benioff joins Yahoo Finance&#x2019;s Brian Sozzi to discuss the company&#x27;s latest earnings, succession plans, activist investors targeting Salesforce, the AI phenomenon, and much more. Be sure to tune into Yahoo Finance Live Programming on Thursday, March 2:- 9am ET:&#x26;nbsp; Brian Sozzi joins Yahoo Finance&#x2019;s Julie Hyman and Brad Smith with his key takeaways from the Marc Benioff interview and the company&#x2019;s next steps- 11am ET: Salesforce Analyst breaks down the company&#x2019;s earnings with Yahoo Finance&#x2019;s Rachelle Akuffo- 3:00pm ET: Dave Briggs and Seana Smith talk with Constellation Research Principal Analyst &#x26; Founder Ray Wang"/>
    <meta property="og:description" content="Salesforce Co-Founder and CEO Marc Benioff joins Yahoo Finance&#x2019;s Brian Sozzi to discuss the company&#x27;s latest earnings, succession plans, activist investors targeting Salesforce, the AI phenomenon, and much more. Be sure to tune into Yahoo Finance Live Programming on Thursday, March 2:- 9am ET:&#x26;nbsp; Brian Sozzi joins Yahoo Finance&#x2019;s Julie Hyman and Brad Smith with his key takeaways from the Marc Benioff interview and the company&#x2019;s next steps- 11am ET: Salesforce Analyst breaks down the company&#x2019;s earnings with Yahoo Finance&#x2019;s Rachelle Akuffo- 3:00pm ET: Dave Briggs and Seana Smith talk with Constellation Research Principal Analyst &#x26; Founder Ray Wang"/>
    <meta property="al:android:app_name" content="Yahoo Finance"/>
    <meta property="al:android:package" content="com.yahoo.mobile.client.android.finance"/>
    <meta name="twitter:site" content="@YahooFinance"/>
    <meta name="twitter:dnt" content="on"/>
    <meta property="og:type" content="article"/>
"""

question = "Who is the CEO of Salesforce?"
# question = "Who is Marc Benioff?"

encoding = processor(html, questions=question, return_tensors="pt", truncation=True)

# for k, v in encoding.items():
#     print(k, v.shape)



with torch.no_grad():
    outputs = model(**encoding)

    answer_start_index = outputs.start_logits.argmax()
    answer_end_index = outputs.end_logits.argmax()

    predict_answer_tokens = encoding.input_ids[0, answer_start_index : answer_end_index + 1]
    a = processor.decode(predict_answer_tokens, skip_special_tokens=False)
    print(a)
